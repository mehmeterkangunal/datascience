# %%
from bs4 import BeautifulSoup
import requests
from urllib.request import Request, urlopen

# %%
url='https://fastfoodnutrition.org/mcdonalds/artisan-grilled-chicken-sandwich'

# %%
response=Request(url, headers={'User-Agent': 'Mozilla/5.0'})
web_byte = urlopen(response).read()

# %%
web_byte
# Out:
# b'\n<!DOCTYPE html>\n<html lang="en">\n<head>\n<link rel="preload" href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,700&display=swap" as="style">\n<meta charset="UTF-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<meta property="og:site_name" content="FastFoodNutrition.org" />\n<meta property="og:type" content="Website" />\n<meta property="og:url" content="https://fastfoodnutrition.org/mcdonalds/artisan-grilled-chicken-sandwich" />\n<meta property="twitter:url" content="https://fastfoodnutrition.org/mcdonalds/artisan-grilled-chicken-sandwich" />\n<link rel="icon" type="image/png" href="https://fastfoodnutrition.org/favicon.png" sizes="16x16">\n<meta name="google-site-verification" content="uwY4KDvAqjtaNa915c-BSMoZL72Q-vDvBDAn45cmYDA" />\n<meta property="fb:app_id" content="510431215760752" />\n<link rel="canonical" href="https://fastfoodnutrition.org/mcdonalds/artisan-grilled-chicken-s
# ...

# %%
page=web_byte

# %%
soup=BeautifulSoup(page, "lxml")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link as="style" href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,700&amp;display=swap" rel="preload"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="FastFoodNutrition.org" property="og:site_name"/>
# <meta content="Website" property="og:type"/>
# <meta content="https://fastfoodnutrition.org/mcdonalds/artisan-grilled-chicken-sandwich" property="og:url"/>
# <meta content="https://fastfoodnutrition.org/mcdonalds/artisan-grilled-chicken-sandwich" property="twitter:url"/>
# <link href="https://fastfoodnutrition.org/favicon.png" rel="icon" sizes="16x16" type="image/png"/>
# <meta content="uwY4KDvAqjtaNa915c-BSMoZL72Q-vDvBDAn45cmYDA" name="google-site-verification"/>
# <meta content="510431215760752" property="fb:app_id"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link as="style" href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,700&amp;display=swap" rel="preload"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="FastFoodNutrition.org" property="og:site_name"/>
#   <meta content="Website" property="og:type"/>
#   <meta content="https://fastfoodnutrition.org/mcdonalds/artisan-grilled-chicken-sandwich" property="og:url"/>
#   <meta content="https://fastfoodnutrition.org/mcdonalds/artisan-grilled-chicken-sandwich" property="twitter:url"/>
#   <link href="https://fastfoodnutrition.org/favicon.png" rel="icon" sizes="16x16" type="image/png"/>
#   <meta content="uwY4KDvAqjtaNa915c-BSMoZL72Q-vDvBDAn45cmYDA" name="google-site-verification"/>
#   <meta content="510431215760752" property="fb:app_id"/>
# ...

# %%
soup.find('table')
# Out:
# <table class="item_nutrition">
# <tr class="calories">
# <td>
# <a href="/glossary/serving-size-definition" title="Serving Size Definition">
# Serving Size
# </a>
# </td>
# <td colspan="2" title="Serving size for a McDonald's Artisan Grilled Chicken Sandwich"> 1 sandwich</td>
# </tr>
# <tr>
# <td class="nfactl">
# <a href="/glossary/calories-definition" title="Calories Definition">
# <span class="f700">Calories</span>
# </a>
# </td>
# <td colspan="2" title="Calories in a McDonald's Artisan Grilled Chicken Sandwich">
# 380
# </td>
# </tr>
# <tr class="calories">
# <td>
# <a href="/glossary/calories-from-fat-definition" title="Calories From Fat Definition">Calories From Fat</a>
# </td>
# <td colspan="2" title="Calories from fat in a McDonald's Artisan Grilled Chicken Sandwich">
# 60
# </td>
# </tr>
# <tr>
# <td></td>
# <td class="serving">Amount Per Serving</td>
# <td class="serving nfactr">% Daily Value*</td>
# </tr>
# <tr>
# <td>
# ...

# %%
soup.find('table',class_='item_nutrition')
# Out:
# <table class="item_nutrition">
# <tr class="calories">
# <td>
# <a href="/glossary/serving-size-definition" title="Serving Size Definition">
# Serving Size
# </a>
# </td>
# <td colspan="2" title="Serving size for a McDonald's Artisan Grilled Chicken Sandwich"> 1 sandwich</td>
# </tr>
# <tr>
# <td class="nfactl">
# <a href="/glossary/calories-definition" title="Calories Definition">
# <span class="f700">Calories</span>
# </a>
# </td>
# <td colspan="2" title="Calories in a McDonald's Artisan Grilled Chicken Sandwich">
# 380
# </td>
# </tr>
# <tr class="calories">
# <td>
# <a href="/glossary/calories-from-fat-definition" title="Calories From Fat Definition">Calories From Fat</a>
# </td>
# <td colspan="2" title="Calories from fat in a McDonald's Artisan Grilled Chicken Sandwich">
# 60
# </td>
# </tr>
# <tr>
# <td></td>
# <td class="serving">Amount Per Serving</td>
# <td class="serving nfactr">% Daily Value*</td>
# </tr>
# <tr>
# <td>
# ...

# %%
soup.find('table',class_='item_nutrition').find_all('td')
# Out:
# [<td>
#  <a href="/glossary/serving-size-definition" title="Serving Size Definition">
#  Serving Size
#  </a>
#  </td>,
#  <td colspan="2" title="Serving size for a McDonald's Artisan Grilled Chicken Sandwich"> 1 sandwich</td>,
#  <td class="nfactl">
#  <a href="/glossary/calories-definition" title="Calories Definition">
#  <span class="f700">Calories</span>
#  </a>
#  </td>,
#  <td colspan="2" title="Calories in a McDonald's Artisan Grilled Chicken Sandwich">
#  380
#  </td>,
#  <td>
#  <a href="/glossary/calories-from-fat-definition" title="Calories From Fat Definition">Calories From Fat</a>
#  </td>,
#  <td colspan="2" title="Calories from fat in a McDonald's Artisan Grilled Chicken Sandwich">
#  60
#  </td>,
#  <td></td>,
#  <td class="serving">Amount Per Serving</td>,
#  <td class="serving nfactr">% Daily Value*</td>,
#  <td>
#  <a href="/glossary/fat-definition" title="Fat Definition"><span class="f700">Total Fat</span></a>
#  </td>,
# ...

# %%
runtime_regex = re.compile('Artisan Grilled Chicken Sandwich')

# %%
for i in soup.find_all(title=runtime_regex):
    print(i.text.split())
# Out:
# ['1', 'sandwich']
# ['380']
# ['60']
# ['7g']
# ['11%']
# ['2.0g']
# ['10%']
# ['0.0g']
# ['95mg']
# ['32%']
# ['1110mg']
# ['46%']
# ['44g']
# ['15%']
# ['3g']
# ['12%']
# ['11g']
# ['37g']
# ['74%']
# ['4%']
# ['20%']
# ['20%']
# ['15%']
# []
# []
# ['gluten']
# ['milk']
# ['wheat']
# ['egg']
# ['fish']
# ['peanuts']
# ['shellfish']
# ['soy']
# ['tree', 'nuts']
# ['glutamates']
# ['MSG']
# ['mustard']
# ['nitrates']
# ['seeds']
# ['sesame']
# ['sulfites']

# %%
import re

# %%
runtime_regex = re.compile('healthy')

# %%
hlt=soup.find(title=runtime_regex).get('title')

# %%
hlt=hlt.split()[0][0:2]
print(hlt)
# Out:
# 70

# %%
runtime_regex2 = re.compile('tastes')

# %%
tst=soup.find(title=runtime_regex2).get('title')

# %%
tst=tst.split()[0][0:2]
print(tst)
# Out:
# 82
